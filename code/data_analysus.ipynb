# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_alive = pd.read_excel('./Data alive.xlsx')
df_energy = pd.read_excel('./Data energy.xlsx')
df_packetDelivered = pd.read_excel('./Data packet sent.xlsx')
df_nodeFailure = pd.read_excel('./Data node failure.xlsx')

# %%
plt.text

# %%
fig, ax = plt.subplots(1, 4)
data = [df_alive, df_energy, df_packetDelivered, df_nodeFailure]
for index, params in enumerate(data):
    for method in data[index].columns:
        ax[index].plot(method)
    ax[]
# Out:
# LEACH
# K-Means
# DECKS
# Q-Learning

# %% [markdown]
# $$\min_{\substack{1 \leq i \leq 5 \\ i \neq j}} |x_i - x_j|$$

# %%
x = [i for i in range(10)]
x2 = [i for i in range(10)]
plt.plot(x, x2)
plt.title(r'$\text{Let } \text{min_val} = \min_{\substack{1 \leq i \leq 5 \\ i \neq j}} |x_i - x_j|$')
# Out:
# Text(0.5, 1.0, '$\\text{Let } \\text{min_val} = \\min_{\\substack{1 \\leq i \\leq 5 \\\\ i \\neq j}} |x_i - x_j|$')
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x000001AE28327048> (for post_execute):
# ---------------------------------------------------------------------------
# ParseFatalException                       Traceback (most recent call last)
# s:\Python3.7.3\lib\site-packages\matplotlib\_mathtext.py in parse(self, s, fonts_object, fontsize, dpi)
#    2236         try:
# -> 2237             result = self._expression.parseString(s)
#    2238         except ParseBaseException as err:
#
# s:\Python3.7.3\lib\site-packages\pyparsing\core.py in parse_string(self, instring, parse_all, parseAll)
#    1140                 # catch and re-raise exception from here, clearing out pyparsing internal stack trace
# -> 1141                 raise exc.with_traceback(None)
#    1142         else:
#
# ...
